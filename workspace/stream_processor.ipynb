# %% [markdown]
# # E-Commerce Data Lakehouse with Real-Time CDC
#
# This notebook launches the production-style Spark CDC processor used by the project. The processor includes schema-drift detection, bad-record quarantine, CDC lag metrics, and replay metadata.

# %% [markdown]
# ## Run the CDC stream
# The next cell runs continuously until interrupted. Start the core services and data generator first.

# %%
# %run ./stream_processor.py

# %% [markdown]
# ## Replay preview
# Use the shell command below only after quarantined records exist. Replay is a dry run unless `--execute` is supplied.

# %%
# !python ./replay_quarantine.py --table orders --limit 25
